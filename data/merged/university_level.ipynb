# %%
import os
import pandas as pd
import numpy as np
cwd = os.getcwd()
parentwd = os.path.dirname(cwd)

# %%
parentwd
# Out:
# '/Users/boraberke/drive/kth/kthgit/studyability/data'

# %%
dataset_names = [
    "country_city_universities",
    "university_tuition_fees",
    "university_rankings",
]
paths = dict()
for dataset in dataset_names:
    paths[dataset] = os.path.join(parentwd,f"{dataset}.csv")

# %%
paths
# Out:
# {'country_city_universities': '/Users/boraberke/drive/kth/kthgit/studyability/data/country_city_universities.csv',
#  'university_tuition_fees': '/Users/boraberke/drive/kth/kthgit/studyability/data/university_tuition_fees.csv',
#  'university_rankings': '/Users/boraberke/drive/kth/kthgit/studyability/data/university_rankings.csv'}

# %%
# read datasets
dfs = {}
for name,path in paths.items():
    dfs[name] = pd.read_csv(path)

# %%
dfs["country_city_universities"].head()
# Out:
#                                  university       country        city alpha_2  \
# 0                University of South Africa  South Africa    Pretoria      ZA
# 1                          Cairo University         Egypt       Cairo      EG
# 2  National Autonomous University of Mexico        Mexico      Mexico      MX
# 3                     Alexandria University         Egypt  Alexandria      EG
# 4                      Ain Shams University         Egypt       Cairo      EG
#
#   alpha_3    region                       sub_region
# 0     ZAF    Africa               Sub-Saharan Africa
# 1     EGY    Africa                  Northern Africa
# 2     MEX  Americas  Latin America and the Caribbean
# 3     EGY    Africa                  Northern Africa
# 4     EGY    Africa                  Northern Africa

# %%
dfs["university_tuition_fees"].head()
# Out:
#   2025_rank                                   university  \
# 0         1  Massachusetts Institute of Technology (MIT)
# 1         2                      Imperial College London
# 2         3                         University of Oxford
# 3         4                           Harvard University
# 4         5                      University of Cambridge
#
#    tuition_fee_yearly_usd                  method
# 0                   53790                official
# 1                   44083  scrape-topuniversities
# 2                   40000               estimated
# 3                   50000               estimated
# 4                   40000               estimated

# %%
dfs["university_rankings"].head()
# Out:
#   2025_rank 2024_rank                                    university alpha_2  \
# 0         1         1  Massachusetts Institute of Technology (MIT)       US
# 1         2         6                       Imperial College London      UK
# 2         3         3                          University of Oxford      UK
# 3         4         4                            Harvard University      US
# 4         5         2                       University of Cambridge      UK
#
#    academic_reputation  employer_reputation  international_students  \
# 0                100.0                100.0                    86.8
# 1                 98.5                 99.5                    99.6
# 2                100.0                100.0                    97.7
# 3                100.0                100.0                    69.0
# 4                100.0                100.0                    94.8
#
#    employment_outcomes  sustainability qs_overall_score
# 0                100.0            99.0              100
# 1                 93.4            99.7             98.5
# 2                100.0            85.0             96.9
# 3                100.0            84.4             96.8
# 4                100.0            84.8             96.7

# %%
dfs["university_rankings"].university = dfs["university_rankings"].university.str.title()
dfs["university_rankings"].university = dfs["university_rankings"].university.str.strip()
dfs["university_tuition_fees"].university = dfs["university_tuition_fees"].university.str.title()
dfs["university_tuition_fees"].university = dfs["university_tuition_fees"].university.str.strip()
dfs["country_city_universities"].university = dfs["country_city_universities"].university.str.title()
dfs["country_city_universities"].university = dfs["country_city_universities"].university.str.strip()

# %%
#custom fix for uni names
dfs["university_rankings"] = dfs["university_rankings"].replace("Ucl", "University College London")
dfs["university_tuition_fees"] = dfs["university_tuition_fees"].replace("Ucl", "University College London")

# %%
# not all of the names are matching perfectly. User rapidfuzz to find the closest strings.
from rapidfuzz import process

uni_rankings_uni = dfs["university_rankings"].university.values.tolist()
dfs["university_tuition_fees"]['university'] = dfs["university_tuition_fees"].university.apply(lambda x: process.extractOne(x, uni_rankings_uni)[0])

# %%
country_city_unis = dfs["country_city_universities"].university.values.tolist()
dfs["university_rankings"]['university_closest'] = dfs["university_rankings"].university.apply(lambda x: process.extractOne(x, country_city_unis)[0])

# %%
merged = dfs["university_rankings"].merge(dfs["university_tuition_fees"][['university','tuition_fee_yearly_usd','method']], how="left",on="university")
merged_with_cities = merged.merge(dfs["country_city_universities"][['university',"city",'region','sub_region']], how="left",left_on="university_closest", right_on="university")

# %%
merged_with_cities.head()
# Out:
#   2025_rank 2024_rank                                 university_x alpha_2  \
# 0         1         1  Massachusetts Institute Of Technology (Mit)      US
# 1         2         6                      Imperial College London      UK
# 2         3         3                         University Of Oxford      UK
# 3         4         4                           Harvard University      US
# 4         5         2                      University Of Cambridge      UK
#
#    academic_reputation  employer_reputation  international_students  \
# 0                100.0                100.0                    86.8
# 1                 98.5                 99.5                    99.6
# 2                100.0                100.0                    97.7
# 3                100.0                100.0                    69.0
# 4                100.0                100.0                    94.8
#
#    employment_outcomes  sustainability qs_overall_score  \
# 0                100.0            99.0              100
# 1                 93.4            99.7             98.5
# 2                100.0            85.0             96.9
# 3                100.0            84.4             96.8
# 4                100.0            84.8             96.7
#
#                       university_closest  tuition_fee_yearly_usd  \
# 0  Massachusetts Institute Of Technology                 53790.0
# 1                Imperial College London                 44083.0
# 2                   University Of Oxford                 40000.0
# 3                     Harvard University                 50000.0
# 4                University Of Cambridge                 40000.0
#
#                    method                           university_y       city  \
# 0                official  Massachusetts Institute Of Technology  Cambridge
# 1  scrape-topuniversities                Imperial College London     London
# 2               estimated                   University Of Oxford     Oxford
# 3               estimated                     Harvard University  Cambridge
# 4               estimated                University Of Cambridge  Cambridge
#
#      region        sub_region
# 0  Americas  Northern America
# 1    Europe   Northern Europe
# 2    Europe   Northern Europe
# 3  Americas  Northern America
# 4    Europe   Northern Europe

# %%
# there should not be any null values
# these values are not found in tuition fee dataset
nan_rows = merged_with_cities[merged_with_cities['tuition_fee_yearly_usd'].isnull()]
nan_rows
# Out:
#      2025_rank  2024_rank                                       university_x  \
# 897    851-900   951-1000                 Vietnam National University, Hanoi
# 898    851-900    801-850             Vilnius Gediminas Technical University
# 899    851-900    761-770                   Virginia Commonwealth University
# 900    851-900   951-1000                        Yildiz Technical University
# 902    771-780    801-850                    China University Of Geosciences
# 903  1001-1200  1001-1200                      Harbin Engineering University
# 904    901-950    851-900                                 Catania University
# 908    901-950  1001-1200                        German Jordanian University
# 909    901-950  1001-1200  Imam Mohammad Ibn Saud Islamic University – Imsiu
# 910    901-950    851-900                                Kanazawa University
# 913    901-950    801-850                         Louisiana State University
# 914    901-950   951-1000                                Makerere University
#
#     alpha_2  academic_reputation  employer_reputation  international_students  \
# 897      VN                 15.3                 18.7                     1.2
# 898      LT                  8.7                 13.8                    32.9
# 899      US                  7.1                  8.5                     3.2
# 900      TR                  9.7                 24.7                    18.5
# 902      CN                  5.1                  1.4                     2.7
# 903      CN                  5.4                  2.4                     2.2
# 904      IT                 11.6                  3.0                     4.5
# 908      JO                  8.6                 15.1                    16.3
# 909      SA                 14.8                  7.6                     4.2
# 910      JP                 10.5                  3.9                     5.8
# 913      US                  9.5                  6.7                     3.8
# 914      UG                 11.0                  4.2                     7.5
#
#      employment_outcomes  sustainability qs_overall_score  \
# 897                 60.1             6.4                -
# 898                  6.9             2.0                -
# 899                  8.2             8.5                -
# 900                 19.9            35.1                -
# 902                  1.4             4.0                -
# 903                  3.8             1.3                -
# 904                  5.7             3.6                -
# 908                  8.5             1.5                -
# 909                 26.5             1.0                -
# 910                  1.8             1.6                -
# 913                 18.8            52.8                -
# 914                 98.3             3.5                -
#
#                            university_closest  tuition_fee_yearly_usd method  \
# 897        Vietnam National University, Hanoi                     NaN    NaN
# 898                          Cairo University                     NaN    NaN
# 899          Virginia Commonwealth University                     NaN    NaN
# 900               Yıldız Technical University                     NaN    NaN
# 902   China University Of Geosciences (Wuhan)                     NaN    NaN
# 903             Harbin Engineering University                     NaN    NaN
# 904                     University Of Catania                     NaN    NaN
# 908                          Cairo University                     NaN    NaN
# 909                University Of South Africa                     NaN    NaN
# 910                       Kanazawa University                     NaN    NaN
# 913  Louisiana State University - Baton Rouge                     NaN    NaN
# 914                       Makerere University                     NaN    NaN
#
#                                  university_y         city    region  \
# 897        Vietnam National University, Hanoi        Hanoi      Asia
# 898                          Cairo University        Cairo    Africa
# 899          Virginia Commonwealth University     Richmond  Americas
# 900               Yıldız Technical University     Istanbul      Asia
# 902   China University Of Geosciences (Wuhan)        Wuhan      Asia
# 903             Harbin Engineering University       Harbin      Asia
# 904                     University Of Catania      Catania    Europe
# 908                          Cairo University        Cairo    Africa
# 909                University Of South Africa     Pretoria    Africa
# 910                       Kanazawa University     Kanazawa      Asia
# 913  Louisiana State University - Baton Rouge  Baton Rouge  Americas
# 914                       Makerere University      Kampala    Africa
#
#              sub_region
# 897  South-eastern Asia
# 898     Northern Africa
# 899    Northern America
# 900        Western Asia
# 902        Eastern Asia
# 903        Eastern Asia
# 904     Southern Europe
# 908     Northern Africa
# 909  Sub-Saharan Africa
# 910        Eastern Asia
# 913    Northern America
# 914  Sub-Saharan Africa

# %%
# there should not be any null values
# these values are not found in tuition fee dataset
nan_rows = merged_with_cities[merged_with_cities['city'].isnull()]
nan_rows
# Out:
#     2025_rank 2024_rank                              university_x alpha_2  \
# 218       219       217  National Yang Ming Chiao Tung University      TW
# 485       485       505           National Sun Yat-Sen University      TW
# 618   611-620       577           Taipei Medical University (Tmu)      TW
#
#      academic_reputation  employer_reputation  international_students  \
# 218                 32.9                 62.7                    19.2
# 485                 26.5                 24.9                    10.8
# 618                 10.6                 12.5                    13.7
#
#      employment_outcomes  sustainability qs_overall_score  \
# 218                 58.3            38.8             43.9
# 485                 11.4            48.9             24.8
# 618                  8.1             8.3                -
#
#                            university_closest  tuition_fee_yearly_usd  \
# 218  National Yang Ming Chiao Tung University                 10000.0
# 485           National Sun Yat-Sen University                  8000.0
# 618                 Taipei Medical University                  1800.0
#
#                      method                              university_y city  \
# 218               estimated  National Yang Ming Chiao Tung University  NaN
# 485               estimated           National Sun Yat-Sen University  NaN
# 618  scrape-topuniversities                 Taipei Medical University  NaN
#
#     region    sub_region
# 218   Asia  Eastern Asia
# 485   Asia  Eastern Asia
# 618   Asia  Eastern Asia

# %%
# add university ids
merged_with_cities['university_id'] = merged_with_cities.index

# %%
merged_with_cities = merged_with_cities[['2025_rank',
                                         '2024_rank',
                                         'university_x',
                                         'alpha_2',
                                         'academic_reputation',
                                         'employer_reputation',
                                         'international_students',
                                         'employment_outcomes',
                                         'sustainability',
                                         'qs_overall_score',
                                         'tuition_fee_yearly_usd',
                                         'method',
                                         'city',
                                         'region',
                                         'sub_region',
                                         'university_id']]

# %%
merged_with_cities.to_csv(os.path.join(cwd,"university_level.csv"),index=False, header=['2025_rank',
                                                      '2024_rank',
                                                      'university',
                                                      'country_code',
                                                      'academic_reputation',
                                                      'employer_reputation',
                                                      'international_students',
                                                      'employment_outcomes',
                                                      'sustainability',
                                                      'qs_overall_score',
                                                      'tuition_fee_yearly_usd',
                                                      'method',
                                                      'city',
                                                      'region',
                                                      'sub_region',
                                                      'university_id'])
